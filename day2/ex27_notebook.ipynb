# %% [markdown]
# # Początek
# ## nowa linia
# ### kolejna linia nagłówka
#
# **strong**\
# zwykły tekst\
# nowa linia

# %%
print("Radek")
# Out:
# Radek

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_excel('excel_with_multiple_sheets.xlsx', sheet_name=2)

# %%
df
# Out:
#      Name  Marks
# 0  Addiya    179
# 1   Samen    189
# 2   Darek    199
# 3    John    169

# %%
print(df)
# Out:
#      Name  Marks
# 0  Addiya    179
# 1   Samen    189
# 2   Darek    199
# 3    John    169

# %%
a = "Radek"
a
# Out:
# 'Radek'

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 8.3/8.3 MB 69.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 89.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 7.2/7.2 MB 102.6 MB/s  0:00:00
# ...
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [1, 2, 3, 4, 5]
y = [2, 5, 7, 9, 11]

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.show()  # dla pycharm

# %%
plt.plot(x, y, c="red")

# %%
plt.title("wykres")
plt.plot(x, y, c="red")

# %%
df = pd.DataFrame({"A": [1, 2, 3, 4], "B": [4, 5, 6, 7]})

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df.describe()
# Out:
#               A         B
# count  4.000000  4.000000
# mean   2.500000  5.500000
# std    1.290994  1.290994
# min    1.000000  4.000000
# 25%    1.750000  4.750000
# 50%    2.500000  5.500000
# 75%    3.250000  6.250000
# max    4.000000  7.000000

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter", x="A", y="B", s=32, alpha=.8)
plt.gca().spines[['top', 'right', ]].set_visible(False)
